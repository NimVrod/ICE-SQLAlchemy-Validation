# %%
import pandas as pd

# Wczytanie wyników wygenerowanych przez główny skrypt
df = pd.read_csv('validation_results.csv')

print("--- PODSUMOWANIE WALIDACJI ---")
display(df['Status'].value_counts())

print("\n--- SZCZEGÓŁY BŁĘDÓW ---")
fails_df = df[df['Status'] == 'FAIL']
display(fails_df)
# Out:
# --- PODSUMOWANIE WALIDACJI ---
# Status
# PASS    934
# FAIL     91
# Name: count, dtype: int64
# --- SZCZEGÓŁY BŁĘDÓW ---
#       Row ID Status  Name and surname                         Email  \
# 23        23   FAIL     Hannah Wilson                           NaN
# 24        24   FAIL     Thomas Rogers                           NaN
# 26        26   FAIL   Benjamin Ramsey                           NaN
# 54        54   FAIL   Hannah Mitchell                           NaN
# 74        74   FAIL     Ashley Tanner      jchristensen@example.net
# ...      ...    ...               ...                           ...
# 1020    1020   FAIL  Curtis Hendricks  avilachristopher@example.org
# 1021    1021   FAIL      Donna Garcia      bryanvazquez@example.com
# 1022    1022   FAIL       Joyce Nunez      wilsonjoseph@example.org
# 1023    1023   FAIL       Aaron Klein  jenniferatkinson@example.net
# 1024    1024   FAIL      Kenneth Long           xrogers@example.com
#
# ...
